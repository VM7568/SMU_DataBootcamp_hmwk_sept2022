# %%
import pandas as pd

# %%
file_path = "Resources/cities_vm copy.csv"
df=pd.read_csv(file_path)
df.head()
# Out:
#             city   latitude   longitude weather  temperature  humidity  \
# 0  mount gambier -37.824670  140.782007    Rain        73.63        58
# 1         dikson  73.508389   80.512382  Clouds        -0.18        95
# 2          vaini -21.192567 -175.177280  Clouds        82.69        74
# 3       hermanus -34.417500   19.236111  Clouds        59.85        66
# 4           fare  45.908020   13.516538  Clouds        56.39        96
#
#    pressure  wind_speed
# 0      1008       11.81
# 1      1010        4.56
# 2      1014       10.36
# 3      1018       11.81
# 4      1020        3.44

# %%
print(df.to_html(index=False, classes="table table-striped table-hover"))
# Out:
# <table border="1" class="dataframe table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th>city</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>weather</th>
#       <th>temperature</th>
#       <th>humidity</th>
#       <th>pressure</th>
#       <th>wind_speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>mount gambier</td>
#       <td>-37.824670</td>
#       <td>140.782007</td>
#       <td>Rain</td>
#       <td>73.63</td>
#       <td>58</td>
#       <td>1008</td>
#       <td>11.81</td>
#     </tr>
#     <tr>
#       <td>dikson</td>
#       <td>73.508389</td>
#       <td>80.512382</td>
#       <td>Clouds</td>
#       <td>-0.18</td>
#       <td>95</td>
#       <td>1010</td>
#       <td>4.56</td>
#     </tr>
#     <tr>
#       <td>vaini</td>
#       <td>-21.192567</td>
#       <td>-175.177280</td>
#       <td>Clouds</td>
#       <td>82.69</td>
#       <td>74</td>
#       <td>1014</td>
# ...

# %%
file_path = "Resources/cities.csv"
df2=pd.read_csv(file_path)
df2.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
print(df2.to_html(index=False, classes="table table-striped table-hover"))
# Out:
# <table border="1" class="dataframe table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>jacareacanga</td>
#       <td>0</td>
#       <td>BR</td>
#       <td>1528902000</td>
#       <td>62</td>
#       <td>-6.22</td>
#       <td>-57.76</td>
#       <td>89.60</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>kaitangata</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1528905304</td>
#       <td>94</td>
#       <td>-46.28</td>
#       <td>169.85</td>
#       <td>42.61</td>
#       <td>5.64</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>goulburn</td>
#       <td>20</td>
# ...
